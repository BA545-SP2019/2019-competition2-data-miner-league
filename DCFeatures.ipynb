# %%
import pandas as pd
import numpy as np

# %%
data= pd.read_csv("default of credit card clients - Data.csv",header=1)
data.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#               ...              BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 0             ...                      0          0          0         0
# 1             ...                   3272       3455       3261         0
# 2             ...                  14331      14948      15549      1518
# 3             ...                  28314      28959      29547      2000
# 4             ...                  20940      19146      19131      2000
#
#    PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# ...

# %%
data.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
#checking correlation between all columns using pearson method and kendall
data.corr(method='pearson')
# Out:
#                                   ID  LIMIT_BAL       SEX  EDUCATION  \
# ID                          1.000000   0.026179  0.018497   0.039177
# LIMIT_BAL                   0.026179   1.000000  0.024755  -0.219161
# SEX                         0.018497   0.024755  1.000000   0.014232
# EDUCATION                   0.039177  -0.219161  0.014232   1.000000
# MARRIAGE                   -0.029079  -0.108139 -0.031389  -0.143464
# AGE                         0.018678   0.144713 -0.090874   0.175061
# PAY_0                      -0.030575  -0.271214 -0.057643   0.105364
# PAY_2                      -0.011215  -0.296382 -0.070771   0.121566
# PAY_3                      -0.018494  -0.286123 -0.066096   0.114025
# PAY_4                      -0.002735  -0.267460 -0.060173   0.108793
# PAY_5                      -0.022199  -0.249411 -0.055064   0.097520
# PAY_6                      -0.020270  -0.235195 -0.044008   0.082316
# BILL_AMT1                   0.019389   0.285430 -0.033642   0.023581
# ...

# %%
data.corr(method='kendall')
# Out:
#                                   ID  LIMIT_BAL       SEX  EDUCATION  \
# ID                          1.000000   0.021127  0.015103   0.025881
# LIMIT_BAL                   0.021127   1.000000  0.047417  -0.208192
# SEX                         0.015103   0.047417  1.000000   0.014807
# EDUCATION                   0.025881  -0.208192  0.014807   1.000000
# MARRIAGE                   -0.022994  -0.093919 -0.031345  -0.153241
# AGE                         0.018615   0.134720 -0.076103   0.124254
# PAY_0                      -0.018665  -0.227908 -0.048914   0.115232
# PAY_2                      -0.003708  -0.266910 -0.067033   0.148733
# PAY_3                      -0.006934  -0.258264 -0.062625   0.142953
# PAY_4                      -0.003120  -0.240874 -0.056218   0.134448
# PAY_5                      -0.012192  -0.222620 -0.049893   0.121053
# PAY_6                      -0.004793  -0.205973 -0.040324   0.109514
# BILL_AMT1                   0.007373   0.072070 -0.033588   0.073527
# ...

# %%
#creating index 
features_name= ['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0','PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2','BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']

# %%
features_name
# Out:
# ['LIMIT_BAL',
#  'SEX',
#  'EDUCATION',
#  'MARRIAGE',
#  'AGE',
#  'PAY_0',
#  'PAY_2',
#  'PAY_3',
#  'PAY_4',
#  'PAY_5',
#  'PAY_6',
#  'BILL_AMT1',
#  'BILL_AMT2',
#  'BILL_AMT3',
#  'BILL_AMT4',
#  'BILL_AMT5',
#  'BILL_AMT6',
#  'PAY_AMT1',
#  'PAY_AMT2',
#  'PAY_AMT3',
#  'PAY_AMT4',
#  'PAY_AMT5',
#  'PAY_AMT6']

# %%
# Import train_test_split function
from sklearn.model_selection import train_test_split

# %%
X= data[['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0','PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2','BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']]
y = data['default payment next month']

# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=2019) # 70% training and 30% test

# %%
#Import Random Forest Model
from sklearn.ensemble import RandomForestClassifier

#Create a Gaussian Classifier
clf = RandomForestClassifier(n_estimators=100)

#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(X_train,y_train)

y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.85      0.95      0.89      7063
#           1       0.66      0.37      0.48      1937
#
# avg / total       0.81      0.82      0.80      9000

# %%
feature_imp = pd.Series(clf.feature_importances_,index= features_name).sort_values(ascending= False)

# %%
 feature_imp
# Out:
# PAY_0        0.093433
# AGE          0.068118
# BILL_AMT1    0.061819
# LIMIT_BAL    0.059788
# BILL_AMT2    0.054601
# BILL_AMT3    0.051862
# PAY_AMT1     0.051470
# BILL_AMT5    0.050609
# BILL_AMT6    0.049672
# BILL_AMT4    0.049453
# PAY_AMT2     0.048658
# PAY_AMT3     0.047164
# PAY_AMT6     0.046278
# PAY_2        0.044246
# PAY_AMT5     0.044053
# PAY_AMT4     0.043287
# PAY_3        0.029332
# PAY_5        0.024311
# EDUCATION    0.020443
# PAY_4        0.020007
# PAY_6        0.015471
# MARRIAGE     0.013763
# SEX          0.012161
# dtype: float64

# %% [markdown]
# ## _Top 3 important features/determinants_
# - Pay=
# - Age=
# - Bill_Amt1=

# %%
x1= (data[['AGE','PAY_0','BILL_AMT1']])

# %%
x1.head()
# Out:
#    AGE  PAY_0  BILL_AMT1
# 0   24      2       3913
# 1   26     -1       2682
# 2   34      0      29239
# 3   37      0      46990
# 4   57     -1       8617

# %%
y= data['default payment next month']

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    0
# 3    0
# 4    0
# Name: default payment next month, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
data.hist(alpha=0.5)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd1a969e400>,
# ...
#       dtype=object)

# %%
plt.hist(data,stacked=True, bins=3)

# %%
plt.show()

# %%
x1=data['BILL_AMT1']

# %%
x2= data['PAY_0']

# %%
ax1 = df.plot.scatter(x1 ,y , c='b')
ax2= df.plot.scatter(x2 ,y , c='r')

# %%
plt.style.use('ggplot')

# %%
ax1
